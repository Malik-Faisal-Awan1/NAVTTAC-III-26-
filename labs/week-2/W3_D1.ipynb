# %%
x = [1,2,3,4,5]
num =3
n = num
for i in x[n::]:
    if(n>=0):
        a = i
        print(a, end = " ")
        n -= 1

n = num
for o in x[:n]:
    a = o
    print(a, end = " ")
# Out:
# 4 5 1 2 3

# %%
x = [1,2,3,4,5]
num = 3
y = x.copy()
print(y)
y = x[n:]
print(y)
y = x.copy()
# Out:
# [1, 2, 3, 4, 5]
# [4, 5]
