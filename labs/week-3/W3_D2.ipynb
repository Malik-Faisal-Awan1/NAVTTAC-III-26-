# %%
def mnm(a, b):
    return min(a,b), max(a,b)

mini, maxi = mnm(15, 14)

print(mini, maxi)
# Out:
# 14 15

# %%
num = [1, 2, 3, 2,2, 2, 5, 9,10]
see = set()
nums_l = []
for x in num:
    if x not in see:
        see.add(x)
        nums_l.append(x)
print(nums_l)
# Out:
# [1, 2, 3, 5, 9, 10]
