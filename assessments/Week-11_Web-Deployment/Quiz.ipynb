# %% [markdown]
# # 📝 Quiz — Week 11: Web & Deployment
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** REST, Flask/FastAPI, Databases, Deployment
# **Total Marks: 30** | Time: 35 minutes

# %% [markdown]
# ## Section A — MCQ (1 mark each)
#
# **Q1.** Which HTTP method is used to **retrieve** a resource?
#
# a) POST  b) PUT  c) GET  d) DELETE

# %%
answer_1 = ''

# %% [markdown]
# **Q2.** A REST API returns data in which format most commonly?
#
# a) XML  b) HTML  c) JSON  d) CSV

# %%
answer_2 = ''

# %% [markdown]
# **Q3.** In Flask, `@app.route('/users', methods=['POST'])` defines:
#
# a) A URL that serves a webpage  b) An endpoint that handles POST requests at `/users`  c) A database table  d) A decorator for authentication

# %%
answer_3 = ''

# %% [markdown]
# **Q4.** `SQLite` is best described as:
#
# a) A cloud database service  b) A serverless, file-based relational database  c) A NoSQL database  d) An in-memory only database

# %%
answer_4 = ''

# %% [markdown]
# **Q5.** In FastAPI, `Depends()` is used for:
#
# a) Route grouping  b) Dependency injection (e.g., database sessions)  c) Rate limiting  d) Response formatting

# %%
answer_5 = ''

# %% [markdown]
# **Q6.** Which Streamlit function renders a DataFrame as an interactive table?
#
# a) `st.write(df)`  b) `st.dataframe(df)`  c) `st.table(df)`  d) Both b and c (different styles)

# %%
answer_6 = ''

# %% [markdown]
# ## Section B — True/False (1 mark each)
#
# **Q7.** HTTP status code 404 means the resource was not found.
# **Q8.** A `PUT` request is idempotent (repeating it gives the same result).
# **Q9.** FastAPI automatically generates interactive API docs at `/docs`.
# **Q10.** SQL `JOIN` combines rows from two tables based on a related column.
# **Q11.** Deploying to Heroku or Render requires a `requirements.txt` file.

# %%
answer_7=''
answer_8=''
answer_9=''
answer_10=''
answer_11=''

# %% [markdown]
# ## Short Answer (3 marks each)
#
# **Q12.** What are the four CRUD operations and their corresponding HTTP methods?

# %%
answer_12 = """
...
"""

# %% [markdown]
# **Q13.** What is the difference between Flask and FastAPI? When would you choose each?

# %%
answer_13 = """
...
"""

# %% [markdown]
# **Q14.** Explain what a database migration is and why it is important.

# %%
answer_14 = """
...
"""

# %% [markdown]
# ## Fill in the Blank
#
# **Q15.** A Flask response with `jsonify({'error': 'not found'})` should use status code ___.
# **Q16.** In SQLite, `cursor.___()` executes an SQL statement.

# %%
answer_15=''
answer_16=''

# %% [markdown]
# ## ✅ Answer Key

# %%
answers={1:'c',2:'c',3:'b',4:'b',5:'b',6:'d',7:'True',8:'True',9:'True',10:'True',11:'True',
    12:'Create→POST, Read→GET, Update→PUT/PATCH, Delete→DELETE',
    13:'Flask: minimal, flexible, good for small APIs. FastAPI: modern, async, auto-validation, auto-docs — good for larger/production APIs.',
    14:'A migration is a versioned script that changes the DB schema. Important to keep schema in sync with code across environments.',
    15:'404',16:'execute'}
print('Key loaded.')
