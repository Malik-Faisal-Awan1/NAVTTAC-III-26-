# %% [markdown]
# # 📝 Quiz — Week 5: Object-Oriented Programming
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** Classes, Encapsulation, Magic Methods
# **Total Marks: 25** | Time: 30 minutes

# %% [markdown]
# ## Section A — MCQ (1 mark each)
#
# **Q1.** What is `self` in a class method?
#
# a) A keyword  b) A reference to the current instance  c) A global variable  d) The class itself

# %%
answer_1 = ''

# %% [markdown]
# **Q2.** Which dunder method is called when you do `print(obj)`?
#
# a) `__repr__`  b) `__init__`  c) `__str__`  d) `__print__`

# %%
answer_2 = ''

# %% [markdown]
# **Q3.** A class attribute is shared by:
#
# a) Only the first instance  b) All instances  c) No instances  d) Only subclasses

# %%
answer_3 = ''

# %% [markdown]
# **Q4.** What convention marks an attribute as 'private-style' in Python?
#
# a) `public_attr`  b) `_protected`  c) `__private`  d) Both b and c

# %%
answer_4 = ''

# %% [markdown]
# **Q5.** `@property` allows you to:
#
# a) Define a class method  b) Access a method like an attribute  c) Create a static variable  d) Override `__init__`

# %%
answer_5 = ''

# %% [markdown]
# ## Section B — True/False (1 mark each)
#
# **Q6.** `__init__` is called automatically when an object is created.
# **Q7.** Encapsulation means hiding internal state and exposing a clean interface.
# **Q8.** Class methods receive `cls` as the first argument.
# **Q9.** `__len__` is called when you use `len(obj)`.
# **Q10.** You cannot have multiple constructors in Python.

# %%
answer_6=''
answer_7=''
answer_8=''
answer_9=''
answer_10=''

# %% [markdown]
# ## Section C — Short Answer (3 marks each)
#
# **Q11.** Explain inheritance in OOP with a real-world analogy.

# %%
answer_11 = """
...
"""

# %% [markdown]
# **Q12.** What is the difference between `__str__` and `__repr__`?

# %%
answer_12 = """
...
"""

# %% [markdown]
# **Q13.** Describe how you would use a `@property` setter to validate that age is always positive.

# %%
answer_13 = """
...
"""

# %% [markdown]
# ## Fill in the Blank (1 mark each)
#
# **Q14.** To call the parent class's `__init__` use `___().__init__(...)`.
# **Q15.** A method decorated with `@staticmethod` does not receive `___` or `___` as its first argument.

# %%
answer_14=''
answer_15=''

# %% [markdown]
# ## ✅ Answer Key

# %%
answers={1:'b',2:'c',3:'b',4:'d',5:'b',6:'True',7:'True',8:'True',9:'True',10:'True',
    11:'A Vehicle class is a parent. Car inherits from Vehicle and gets all vehicle properties plus car-specific ones.',
    12:'__str__ is for human-readable output; __repr__ is for developer/debug output. repr should ideally be eval-able.',
    13:'Use @property to get age, @age.setter to set it; inside setter raise ValueError if value <= 0.',
    14:'super',15:'self, cls'}
print('Key loaded.')
