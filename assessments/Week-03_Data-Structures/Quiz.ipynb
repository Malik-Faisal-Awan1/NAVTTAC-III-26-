# %% [markdown]
# # 📝 Quiz — Week 3: Data Structures
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** Lists, Tuples, Sets, Dictionaries, Comprehensions
# **Total Marks: 25** | Time: 30 minutes

# %% [markdown]
# ## Section A — Multiple Choice (1 mark each)
#
# **Q1.** Which data structure preserves insertion order AND allows duplicates AND is mutable?
#
# a) Set
# b) Tuple
# c) List
# d) Frozenset

# %%
answer_1 = ''

# %% [markdown]
# **Q2.** What is the output of `{1, 2, 3} & {2, 3, 4}`?
#
# a) `{1, 2, 3, 4}`
# b) `{2, 3}`
# c) `{1, 4}`
# d) `{1, 2, 3, 4}` minus `{2, 3}`

# %%
answer_2 = ''

# %% [markdown]
# **Q3.** What does `dict.get('key', 'default')` return if `'key'` is absent?
#
# a) `None`
# b) `KeyError`
# c) `'default'`
# d) `False`

# %%
answer_3 = ''

# %% [markdown]
# **Q4.** The expression `[x**2 for x in range(5) if x % 2 == 0]` produces:
#
# a) `[0, 4, 16]`
# b) `[1, 9, 25]`
# c) `[0, 1, 4, 9, 16]`
# d) `[4, 16]`

# %%
answer_4 = ''

# %% [markdown]
# **Q5.** Which method returns an iterable of `(key, value)` tuples from a dictionary?
#
# a) `keys()`
# b) `values()`
# c) `items()`
# d) `pairs()`

# %%
answer_5 = ''

# %% [markdown]
# ## Section B — True / False (1 mark each)
#
# **Q6.** Tuples can be used as dictionary keys because they are hashable.
# **Q7.** `list.sort()` returns a new sorted list.
# **Q8.** A set comprehension uses `{}` with an expression (no colon).
# **Q9.** `dict.update(other)` modifies the original dict in-place.
# **Q10.** `frozenset` is a mutable, hashable version of a set.

# %%
answer_6=''
answer_7=''
answer_8=''
answer_9=''
answer_10=''

# %% [markdown]
# ## Section C — Short Answer (3 marks each)
#
# **Q11.** Explain the difference between a **shallow copy** and a **deep copy** of a list.

# %%
answer_11 = """
...
"""

# %% [markdown]
# **Q12.** Write a one-liner dict comprehension that squares numbers 1-5: `{1: 1, 2: 4, 3: 9, 4: 16, 5: 25}`.

# %%
answer_12 = None  # replace with your one-liner
print(answer_12)

# %% [markdown]
# **Q13.** What is tuple unpacking? Show an example of swapping two variables using it.

# %%
answer_13 = """
...
"""

# %% [markdown]
# ## Section D — Fill in the Blank (1 mark each)
#
# **Q14.** To add a key-value pair to a dict `d`, write `d___ = value`.
# **Q15.** The `___` operator removes and returns an element from a set.

# %%
answer_14 = ''
answer_15 = ''

# %% [markdown]
# ---
# ## ✅ Answer Key

# %%
answers = {1:'c',2:'b',3:'c',4:'a',5:'c',6:'True',7:'False',8:'True',9:'True',10:'False',
    11:'Shallow copy copies the outer container; nested objects are shared. Deep copy recursively copies everything.',
    12:'{n: n**2 for n in range(1,6)}',
    13:'Tuple unpacking assigns tuple elements to variables. Swap: a, b = b, a',
    14:'[new_key]',15:'discard or remove or pop'}
print('Answer key loaded.')
