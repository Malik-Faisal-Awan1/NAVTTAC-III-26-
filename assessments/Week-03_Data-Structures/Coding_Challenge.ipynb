# %% [markdown]
# # 💻 Coding Challenge — Week 3: Data Structures
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** Lists, Tuples, Sets, Dictionaries, Comprehensions
# **Total Marks: 25** | Time: 45 minutes

# %% [markdown]
# ## Challenge 1 — List Operations (5 marks)
#
# Write a function `top_n(numbers, n)` that:
# - Takes a list of numbers and an integer `n`
# - Returns the top `n` **unique** values in **descending** order
# - Does not modify the original list

# %%
# ─── YOUR CODE HERE ───────────────────────────────────────────
def top_n(numbers: list, n: int) -> list:
    pass
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert top_n([3, 1, 4, 1, 5, 9, 2, 6, 5, 3], 3) == [9, 6, 5]
assert top_n([1, 1, 1], 2) == [1]
assert top_n([5, 3, 1], 5) == [5, 3, 1]
print('✅ top_n passed — 5/5 marks')

# %% [markdown]
# ## Challenge 2 — Dictionary Aggregation (5 marks)
#
# Write a function `group_by_initial(words)` that:
# - Takes a list of words
# - Returns a dict where keys are **uppercase** first letters and values are **sorted lists** of matching words

# %%
# ─── YOUR CODE HERE ───────────────────────────────────────────
def group_by_initial(words: list) -> dict:
    pass
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
result = group_by_initial(['apple', 'banana', 'avocado', 'blueberry', 'cherry'])
assert result == {'A': ['apple', 'avocado'], 'B': ['banana', 'blueberry'], 'C': ['cherry']}
print('✅ group_by_initial passed — 5/5 marks')

# %% [markdown]
# ## Challenge 3 — Set Operations (5 marks)
#
# Given two lists of student names, write a function `attendance_report(class_a, class_b)` that returns a dict with:
# - `'both'`: students in both classes
# - `'only_a'`: students only in class A
# - `'only_b'`: students only in class B
# - `'total_unique'`: count of all unique students

# %%
# ─── YOUR CODE HERE ───────────────────────────────────────────
def attendance_report(class_a: list, class_b: list) -> dict:
    pass
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
a = ['Ali', 'Sara', 'Tom']
b = ['Sara', 'Tom', 'Zara']
r = attendance_report(a, b)
assert r['both'] == {'Sara', 'Tom'}
assert r['only_a'] == {'Ali'}
assert r['only_b'] == {'Zara'}
assert r['total_unique'] == 4
print('✅ attendance_report passed — 5/5 marks')

# %% [markdown]
# ## Challenge 4 — Comprehensions (5 marks)
#
# Using **comprehensions only** (no explicit loops), write:
#
# 1. `even_squares(n)` — list of squares of even numbers from 0 to n (exclusive)
# 2. `char_count(text)` — dict of character → count (ignore spaces)
# 3. `unique_lengths(words)` — set of word lengths

# %%
# ─── YOUR CODE HERE ───────────────────────────────────────────
def even_squares(n: int) -> list:
    pass

def char_count(text: str) -> dict:
    pass

def unique_lengths(words: list) -> set:
    pass
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert even_squares(10) == [0, 4, 16, 36, 64]
assert char_count('hello') == {'h':1,'e':1,'l':2,'o':1}
assert unique_lengths(['hi','hello','hey','world']) == {2,3,5}
print('✅ Comprehensions passed — 5/5 marks')

# %% [markdown]
# ## Challenge 5 — Nested Data (5 marks)
#
# You have a list of student records:
# ```python
# students = [
#     {'name': 'Ali',   'scores': [85, 90, 78]},
#     {'name': 'Sara',  'scores': [92, 88, 95]},
#     {'name': 'Omar',  'scores': [70, 65, 80]},
# ]
# ```
# Write `summarize_students(students)` that returns a list of dicts:
# `[{'name': ..., 'average': ..., 'grade': ...}]`
# Grade: A (≥90), B (≥80), C (≥70), D (≥60), F (<60)

# %%
students = [
    {'name': 'Ali',   'scores': [85, 90, 78]},
    {'name': 'Sara',  'scores': [92, 88, 95]},
    {'name': 'Omar',  'scores': [70, 65, 80]},
]

# ─── YOUR CODE HERE ───────────────────────────────────────────
def summarize_students(students: list) -> list:
    pass
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
result = summarize_students(students)
assert result[0] == {'name': 'Ali',  'average': round((85+90+78)/3,2), 'grade': 'B'}
assert result[1]['grade'] == 'A'
assert result[2]['grade'] == 'C'
print('✅ summarize_students passed — 5/5 marks')
