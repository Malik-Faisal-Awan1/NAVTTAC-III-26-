# %% [markdown]
# # 📝 Quiz — Week 1-2: Python Fundamentals
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** Strings, Control Flow, Modules, Imports
# **Total Marks: 25** | Time: 30 minutes
#
# ---
# > Answer every question in the cell directly below it.
# > MCQ: write the letter. Short answer: 1-3 sentences. True/False: write True or False.

# %% [markdown]
# ## Section A — Multiple Choice Questions (1 mark each)
#
# **Q1.** What does `'hello'[::-1]` return?
#
# a) `'hello'`
# b) `'olleh'`
# c) `'hell'`
# d) Error

# %%
# A1 — write the letter of your answer
answer_1 = 'b'  # e.g. answer_1 = 'b'

# %% [markdown]
# **Q2.** Which method removes **leading and trailing whitespace** from a string?
#
# a) `strip()`
# b) `replace()`
# c) `split()`
# d) `clean()`

# %%
answer_2 = 'a'

# %% [markdown]
# **Q3.** What is the output of `bool('')`?
#
# a) `True`
# b) `False`
# c) `None`
# d) `0`

# %%
answer_3 = 'b'

# %% [markdown]
# **Q4.** Which import style lets you call `sqrt(4)` without a prefix?
#
# a) `import math`
# b) `import math as m`
# c) `from math import sqrt`
# d) `from math import *` only

# %%
answer_4 = 'c'

# %% [markdown]
# **Q5.** What does the `casefold()` method do differently from `lower()`?
#
# a) Nothing — they are identical
# b) It is more aggressive; handles special Unicode characters
# c) It only works on ASCII
# d) It converts to uppercase first

# %%
answer_5 = 'b'

# %% [markdown]
# ## Section B — True / False (1 mark each)
#
# **Q6.** Python strings are mutable.
# **Q7.** `'a' or 'b'` evaluates to `'a'` because of short-circuit logic.
# **Q8.** `split()` without arguments splits on any whitespace and discards empty strings.
# **Q9.** `import os` and `from os import path` load different modules.
# **Q10.** `casefold()` is the preferred method for case-insensitive comparisons.

# %%
answer_6  = 'False'
answer_7  = 'True'
answer_8  = 'False'
answer_9  = 'True'
answer_10 = 'True'

# %% [markdown]
# ## Section C — Short Answer (3 marks each)
#
# **Q11.** Explain what a *truthy* value is in Python. Give two examples of truthy and two of falsy values.

# %%
# Write your answer as a Python comment or string
answer_11 = """Values that return true on a function call, i.e True, 1, False, 0
...
"""

# %% [markdown]
# **Q12.** What is the difference between `import random` and `from random import randint`? When would you prefer each?

# %%
answer_12 = """If i have to use only the randint function from the random libaray i would likely use second option and in case i want a mix of values from rand libaray i will be using whole library
...
"""

# %% [markdown]
# **Q13.** Describe what `str.join()` does. Write the one-liner to turn `['Mon', 'Tue', 'Wed']` into `'Mon, Tue, Wed'`.

# %%
answer_13 = """
...
"""
# Your one-liner:
days = ['Mon', 'Tue', 'Wed']
result = None  # replace None with your solution
print(result)

# %% [markdown]
# ## Section D — Fill in the Blank (1 mark each)
#
# **Q14.** The `___` operator is used for short-circuit AND evaluation.
# **Q15.** `'hello world'.___()` returns `['hello', 'world']`.

# %%
answer_14 = ''
answer_15 = ''

# %% [markdown]
# ---
# ## ✅ Answer Key
# > *Expand only after attempting all questions.*

# %%
answers = {
    1: 'b', 2: 'a', 3: 'b', 4: 'c', 5: 'b',
    6: 'False', 7: 'True', 8: 'True', 9: 'False', 10: 'True',
    11: 'A truthy value is any value Python treats as True in a boolean context. Truthy: non-empty string, non-zero int. Falsy: 0, \'\', None, [], {}.',
    12: 'import random loads the full module; use random.randint(). from random import randint imports only that function; less verbose for frequent use.',
    13: 'join() concatenates an iterable with a separator. One-liner: ", ".join(days)',
    14: 'and', 15: 'split'
}
print('Answer key loaded.')
