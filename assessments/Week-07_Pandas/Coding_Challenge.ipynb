# %% [markdown]
# # 💻 Coding Challenge — Week 7: Pandas
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** DataFrames, Cleaning, GroupBy, Merge, Visualization
# **Total Marks: 25** | Time: 45 minutes

# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('Agg')  # non-interactive backend
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Challenge 1 — DataFrame Creation & Selection (5 marks)
#
# Create the following DataFrame and perform selections:
#
# | name  | dept        | salary | years |
# |-------|-------------|--------|-------|
# | Ali   | Engineering | 75000  | 3     |
# | Sara  | Marketing   | 62000  | 7     |
# | Omar  | Engineering | 82000  | 5     |
# | Zara  | Marketing   | 59000  | 2     |
# | Bilal | Engineering | 91000  | 10    |
#
# 1. `engineers` — only Engineering rows
# 2. `senior` — rows where years ≥ 5
# 3. `avg_salary` — average salary per department (Series)

# %%
# ─── YOUR CODE HERE ───────────────────────────────────────────
data = {
    'name':   ['Ali','Sara','Omar','Zara','Bilal'],
    'dept':   ['Engineering','Marketing','Engineering','Marketing','Engineering'],
    'salary': [75000,62000,82000,59000,91000],
    'years':  [3,7,5,2,10]
}
df = pd.DataFrame(data)

engineers = None
senior = None
avg_salary = None
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert len(engineers) == 3 and all(engineers['dept'] == 'Engineering')
assert len(senior) == 3
assert abs(avg_salary['Engineering'] - (75000+82000+91000)/3) < 0.1
print('✅ Selection/GroupBy passed — 5/5 marks')

# %% [markdown]
# ## Challenge 2 — Data Cleaning (5 marks)
#
# Clean the messy DataFrame below:
# 1. Remove duplicate rows
# 2. Fill missing `salary` with the **median** salary
# 3. Strip whitespace from `name` column
# 4. Convert `years` to integer type

# %%
messy = pd.DataFrame({
    'name':   ['  Ali', 'Sara ', 'Omar', 'Ali  ', 'Zara'],
    'salary': [75000, None, 82000, 75000, None],
    'years':  ['3', '7', '5', '3', '2']
})

# ─── YOUR CODE HERE ───────────────────────────────────────────
clean = None  # perform all cleaning on a copy
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert len(clean) == 4, f'Expected 4 rows after dedup, got {len(clean)}'
assert clean['salary'].isna().sum() == 0
assert all(clean['name'] == clean['name'].str.strip())
assert clean['years'].dtype in [int, 'int64', 'int32']
print('✅ Data cleaning passed — 5/5 marks')

# %% [markdown]
# ## Challenge 3 — GroupBy & Aggregation (5 marks)
#
# Using the original `df` from Challenge 1:
# 1. `dept_stats` — DataFrame with columns: dept, mean_salary, max_salary, employee_count
# 2. `top_earner` — name of the highest-paid employee in each department (Series)

# %%
# ─── YOUR CODE HERE ───────────────────────────────────────────
dept_stats = None
top_earner = None
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert set(dept_stats.columns) >= {'mean_salary','max_salary','employee_count'}
assert top_earner['Engineering'] == 'Bilal'
assert top_earner['Marketing'] == 'Sara'
print('✅ GroupBy passed — 5/5 marks')

# %% [markdown]
# ## Challenge 4 — Merge (5 marks)
#
# Merge the two DataFrames below to get a combined table with `name`, `dept`, `salary`, and `bonus`. Use a left join on `name`.

# %%
employees = pd.DataFrame({'name':['Ali','Sara','Omar','Zara'],'dept':['Eng','Mkt','Eng','Mkt'],'salary':[75,62,82,59]})
bonuses   = pd.DataFrame({'name':['Ali','Omar','Extra'],'bonus':[5000,7000,3000]})

# ─── YOUR CODE HERE ───────────────────────────────────────────
merged = None
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert len(merged) == 4
assert 'bonus' in merged.columns
assert merged.loc[merged['name']=='Sara','bonus'].isna().any()
assert merged.loc[merged['name']=='Ali','bonus'].values[0] == 5000
print('✅ Merge passed — 5/5 marks')

# %% [markdown]
# ## Challenge 5 — Visualization (5 marks)
#
# Create a 2-panel figure (1 row × 2 cols):
# - Left: Bar chart of **average salary by department**
# - Right: Scatter plot of **years vs salary**, colored by department
#
# Add titles, axis labels, and a legend to the scatter plot. Save as `salary_analysis.png`.

# %%
# ─── YOUR CODE HERE ───────────────────────────────────────────
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
# your plotting code here
plt.tight_layout()
plt.savefig('salary_analysis.png', dpi=80)
plt.close()
print('Chart saved.')
# ──────────────────────────────────────────────────────────────
