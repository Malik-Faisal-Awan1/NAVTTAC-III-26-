# %% [markdown]
# # 📝 Quiz — Week 7: Pandas
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** Series, DataFrame, Cleaning, GroupBy, Visualization
# **Total Marks: 25** | Time: 30 minutes

# %% [markdown]
# ## Section A — MCQ (1 mark each)
#
# **Q1.** To select rows where column `age > 30` in DataFrame `df`, you write:
#
# a) `df[df.age > 30]`  b) `df.select(age > 30)`  c) `df.query_age(30)`  d) `df.loc(age > 30)`

# %%
answer_1 = ''

# %% [markdown]
# **Q2.** `df.dropna()` by default:
#
# a) Fills NaN with 0  b) Drops rows with any NaN  c) Drops only columns with all NaN  d) Raises an error

# %%
answer_2 = ''

# %% [markdown]
# **Q3.** `df.groupby('city')['sales'].sum()` returns:
#
# a) A DataFrame  b) A Series indexed by city  c) A list  d) A dictionary

# %%
answer_3 = ''

# %% [markdown]
# **Q4.** `pd.merge(df1, df2, on='id', how='left')` keeps:
#
# a) Only matching rows  b) All rows from df1  c) All rows from df2  d) All rows from both

# %%
answer_4 = ''

# %% [markdown]
# **Q5.** Which Seaborn function is best for showing distribution of one numerical variable?
#
# a) `sns.barplot`  b) `sns.scatterplot`  c) `sns.histplot`  d) `sns.lineplot`

# %%
answer_5 = ''

# %% [markdown]
# ## Section B — True/False (1 mark each)
#
# **Q6.** `df.iloc[0]` selects by label, while `df.loc[0]` selects by integer position.
# **Q7.** `df['col'].apply(func)` applies `func` to every element of the column.
# **Q8.** `df.fillna(method='ffill')` fills NaN with the next valid value.
# **Q9.** A Pandas `Series` can hold mixed data types.
# **Q10.** `df.pivot_table` can compute aggregations while reshaping data.

# %%
answer_6=''
answer_7=''
answer_8=''
answer_9=''
answer_10=''

# %% [markdown]
# ## Section C — Short Answer (3 marks each)
#
# **Q11.** What is the difference between `merge` and `concat` in Pandas?

# %%
answer_11 = """
...
"""

# %% [markdown]
# **Q12.** Name three common data quality issues and how Pandas helps handle them.

# %%
answer_12 = """
...
"""

# %% [markdown]
# **Q13.** When would you choose a boxplot over a histogram?

# %%
answer_13 = """
...
"""

# %% [markdown]
# ## Fill in the Blank (1 mark each)
#
# **Q14.** `df.___('col')` sorts the DataFrame by column `col` in ascending order.
# **Q15.** `df.describe()` returns statistics for ___ columns by default.

# %%
answer_14=''
answer_15=''

# %% [markdown]
# ## ✅ Answer Key

# %%
answers={1:'a',2:'b',3:'b',4:'b',5:'c',6:'False',7:'True',8:'False',9:'True',10:'True',
    11:'merge joins on a key column (SQL-style); concat stacks DataFrames vertically or horizontally.',
    12:'Missing values (dropna/fillna), duplicates (drop_duplicates), wrong types (astype).',
    13:'Boxplot shows median, quartiles, and outliers; better for comparing distributions across groups.',
    14:'sort_values',15:'numeric'}
print('Key loaded.')
