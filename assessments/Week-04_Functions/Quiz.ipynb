# %% [markdown]
# # 📝 Quiz — Week 4: Functions
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** Function Fundamentals, Parameters, Scope, Functional Tools
# **Total Marks: 25** | Time: 30 minutes

# %% [markdown]
# ## Section A — MCQ (1 mark each)
#
# **Q1.** What is printed?
# ```python
# def f(x, y=10): return x + y
# print(f(5))
# ```
# a) Error  b) 5  c) 15  d) 10

# %%
answer_1 = ''

# %% [markdown]
# **Q2.** `*args` allows a function to accept:
#
# a) Any keyword arguments  b) Any number of positional arguments  c) Only integers  d) No arguments

# %%
answer_2 = ''

# %% [markdown]
# **Q3.** What does the LEGB rule describe?
#
# a) Python's list ordering  b) The order Python searches for variable names  c) Lambda syntax  d) The order of function parameters

# %%
answer_3 = ''

# %% [markdown]
# **Q4.** What does `map(str, [1,2,3])` return?
#
# a) `['1','2','3']`  b) A map object  c) `[1,2,3]`  d) `'123'`

# %%
answer_4 = ''

# %% [markdown]
# **Q5.** Which keyword makes a variable inside a nested function refer to the enclosing function's scope?
#
# a) `global`  b) `outer`  c) `nonlocal`  d) `enclosing`

# %%
answer_5 = ''

# %% [markdown]
# ## Section B — True/False (1 mark each)
#
# **Q6.** A function without a `return` statement returns `None`.
# **Q7.** Lambda functions can contain multiple statements.
# **Q8.** Default parameter values are evaluated once at function definition time.
# **Q9.** `filter(func, iterable)` returns items where `func` returns `True`.
# **Q10.** Keyword-only arguments must come before `*args`.

# %%
answer_6=''
answer_7=''
answer_8=''
answer_9=''
answer_10=''

# %% [markdown]
# ## Section C — Short Answer (3 marks each)
#
# **Q11.** Explain the difference between `*args` and `**kwargs` with an example.

# %%
answer_11 = """
...
"""

# %% [markdown]
# **Q12.** What is a closure? Write a short example.

# %%
answer_12 = """
...
"""

# %% [markdown]
# **Q13.** What is the base case in recursion and why is it necessary?

# %%
answer_13 = """
...
"""

# %% [markdown]
# ## Fill in the Blank (1 mark each)
#
# **Q14.** `sorted([3,1,2], key=lambda x: ___)` sorts in descending order.
# **Q15.** A function that takes another function as an argument is called a `___` function.

# %%
answer_14=''
answer_15=''

# %% [markdown]
# ## ✅ Answer Key

# %%
answers={1:'c',2:'b',3:'b',4:'b',5:'c',6:'True',7:'False',8:'True',9:'True',10:'False',
    11:'*args collects extra positional args into a tuple; **kwargs collects extra keyword args into a dict.',
    12:'A closure is an inner function that remembers the enclosing scope even after the outer function returns.',
    13:'The base case stops recursion. Without it the function calls itself forever causing a RecursionError.',
    14:'-x',15:'higher-order'}
print('Key loaded.')
