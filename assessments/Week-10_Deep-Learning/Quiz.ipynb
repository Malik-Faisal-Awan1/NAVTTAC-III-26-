# %% [markdown]
# # 📝 Quiz — Week 10: Deep Learning
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** Neural Networks, PyTorch, Training, Applied DL
# **Total Marks: 30** | Time: 35 minutes

# %% [markdown]
# ## Section A — MCQ (1 mark each)
#
# **Q1.** A **neuron** in a neural network computes:
#
# a) `output = max(inputs)`  b) `output = activation(weights·inputs + bias)`  c) `output = mean(inputs)`  d) `output = inputs²`

# %%
answer_1 = ''

# %% [markdown]
# **Q2.** Which activation function is most commonly used in **hidden layers** of deep networks today?
#
# a) Sigmoid  b) Tanh  c) ReLU  d) Softmax

# %%
answer_2 = ''

# %% [markdown]
# **Q3.** In PyTorch, `torch.Tensor` is:
#
# a) A Python list  b) A multi-dimensional array with autograd support  c) A DataFrame  d) A dictionary

# %%
answer_3 = ''

# %% [markdown]
# **Q4.** `optimizer.zero_grad()` is called before `loss.backward()` because:
#
# a) It resets model weights  b) PyTorch accumulates gradients by default — we need to clear them  c) It speeds up computation  d) It's required by the loss function

# %%
answer_4 = ''

# %% [markdown]
# **Q5.** **Dropout** during training:
#
# a) Removes features permanently  b) Randomly zeroes neurons to reduce overfitting  c) Increases learning rate  d) Clips gradients

# %%
answer_5 = ''

# %% [markdown]
# **Q6.** The **softmax** activation in the output layer is used for:
#
# a) Binary classification  b) Multi-class classification  c) Regression  d) Clustering

# %%
answer_6 = ''

# %% [markdown]
# ## Section B — True/False (1 mark each)
#
# **Q7.** Backpropagation uses the chain rule to compute gradients.
# **Q8.** A higher learning rate always leads to better convergence.
# **Q9.** Batch normalization helps stabilize and speed up training.
# **Q10.** `nn.CrossEntropyLoss` in PyTorch applies softmax internally.
# **Q11.** Transfer learning reuses a pre-trained model on a new task.

# %%
answer_7=''
answer_8=''
answer_9=''
answer_10=''
answer_11=''

# %% [markdown]
# ## Short Answer (3 marks each)
#
# **Q12.** Explain what an epoch, a batch, and an iteration are in deep learning training.

# %%
answer_12 = """
...
"""

# %% [markdown]
# **Q13.** What problem does the vanishing gradient solve with ReLU vs Sigmoid?

# %%
answer_13 = """
...
"""

# %% [markdown]
# **Q14.** Compare PyTorch and Keras/TensorFlow: when would you choose each?

# %%
answer_14 = """
...
"""

# %% [markdown]
# ## Fill in the Blank
#
# **Q15.** `loss.___()` computes gradients via backpropagation.
# **Q16.** `optimizer.___()` updates the model weights.

# %%
answer_15=''
answer_16=''

# %% [markdown]
# ## ✅ Answer Key

# %%
answers={1:'b',2:'c',3:'b',4:'b',5:'b',6:'b',7:'True',8:'False',9:'True',10:'True',11:'True',
    12:'Epoch = one full pass through the dataset. Batch = subset of data processed together. Iteration = one forward+backward pass on one batch.',
    13:'Sigmoid gradient vanishes near 0/1, slowing learning. ReLU gradient is 1 for positive inputs, preventing vanishing.',
    14:'PyTorch: research, flexibility, dynamic graphs. Keras/TF: production, high-level APIs, easier deployment.',
    15:'backward',16:'step'}
print('Key loaded.')
