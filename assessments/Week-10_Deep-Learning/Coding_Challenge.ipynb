# %% [markdown]
# # 💻 Coding Challenge — Week 10: Deep Learning
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** PyTorch Tensors, Neural Networks, Training Loop
# **Total Marks: 30** | Time: 60 minutes

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
print(f'PyTorch version: {torch.__version__} ✅')

# %% [markdown]
# ## Challenge 1 — Tensor Operations (6 marks)
#
# Without using loops:
# 1. Create a tensor `a` = 3×4 of ones (dtype float32)
# 2. Create a tensor `b` = 3×4 of random floats (use `torch.manual_seed(42)`)
# 3. `c` = element-wise product of `a` and `b`
# 4. `row_sums` = sum of each row of `c` (shape: `(3,)`)
# 5. `mean_val` = scalar mean of all elements in `c`

# %%
torch.manual_seed(42)

# ─── YOUR CODE HERE ───────────────────────────────────────────
a         = None
b         = None
c         = None
row_sums  = None
mean_val  = None
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert a.shape == (3,4) and a.dtype == torch.float32
assert b.shape == (3,4)
assert row_sums.shape == (3,)
assert isinstance(mean_val.item(), float)
print('✅ Tensor operations passed — 6/6 marks')

# %% [markdown]
# ## Challenge 2 — Build a Neural Network (6 marks)
#
# Define a class `SimpleNet(nn.Module)` with architecture:
# - Input layer: `input_dim` features
# - Hidden layer 1: 64 neurons + ReLU
# - Hidden layer 2: 32 neurons + ReLU
# - Output layer: `output_dim` neurons (no activation — raw logits)
#
# Test with `input_dim=10, output_dim=2`.

# %%
# ─── YOUR CODE HERE ───────────────────────────────────────────
class SimpleNet(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        # define layers
        pass

    def forward(self, x):
        # define forward pass
        pass
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
model = SimpleNet(10, 2)
test_in = torch.randn(8, 10)
test_out = model(test_in)
assert test_out.shape == (8, 2), f'Expected (8,2) got {test_out.shape}'
total_params = sum(p.numel() for p in model.parameters())
print(f'Model output shape: {test_out.shape}')
print(f'Total parameters: {total_params}')
print('✅ SimpleNet passed — 6/6 marks')

# %% [markdown]
# ## Challenge 3 — Training Loop (6 marks)
#
# Train `SimpleNet` on a classification dataset:
# 1. Generate data: `make_classification(n_samples=500, n_features=10, n_classes=2, random_state=42)`
# 2. Scale and convert to tensors
# 3. Train for 50 epochs using `Adam` optimizer, `CrossEntropyLoss`
# 4. Print loss every 10 epochs
# 5. Store final training accuracy as `train_acc`

# %%
# Dataset
skX, sky = make_classification(n_samples=500, n_features=10, n_classes=2, random_state=42)
scaler = StandardScaler()
skX = scaler.fit_transform(skX)
X_t = torch.tensor(skX, dtype=torch.float32)
y_t = torch.tensor(sky, dtype=torch.long)

# ─── YOUR CODE HERE ───────────────────────────────────────────
train_acc = None
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert train_acc is not None and train_acc > 0.75, f'Train acc too low: {train_acc}'
print(f'Final training accuracy: {train_acc:.4f}')
print('✅ Training loop passed — 6/6 marks')

# %% [markdown]
# ## Challenge 4 — Overfitting & Dropout (6 marks)
#
# Create `RegularizedNet` — same as `SimpleNet` but add:
# - `nn.Dropout(0.3)` after each ReLU
# - A `model.eval()` call before evaluation (disables dropout)
#
# Train on the same data and compare accuracy on a held-out test set.

# %%
# ─── YOUR CODE HERE ───────────────────────────────────────────
class RegularizedNet(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        pass
    def forward(self, x):
        pass

reg_test_acc = None
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert reg_test_acc is not None and reg_test_acc > 0.70
print(f'RegularizedNet test accuracy: {reg_test_acc:.4f}')
print('✅ Dropout regularization passed — 6/6 marks')

# %% [markdown]
# ## Challenge 5 — Save & Load Model (6 marks)
#
# 1. Save the trained `SimpleNet` weights to `simple_net.pth`
# 2. Create a new `SimpleNet` instance and load the saved weights
# 3. Verify both models produce identical outputs on a test tensor

# %%
# ─── YOUR CODE HERE ───────────────────────────────────────────

# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
model_loaded = SimpleNet(10, 2)
model_loaded.load_state_dict(torch.load('simple_net.pth', weights_only=True))
model_loaded.eval()
with torch.no_grad():
    test_input = torch.randn(4, 10)
    model.eval()
    out1 = model(test_input)
    out2 = model_loaded(test_input)
assert torch.allclose(out1, out2), 'Outputs do not match'
print('✅ Save/Load model passed — 6/6 marks')
