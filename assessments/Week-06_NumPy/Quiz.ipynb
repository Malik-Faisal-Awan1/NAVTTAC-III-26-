# %% [markdown]
# # 📝 Quiz — Week 6: NumPy
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** Arrays, Indexing, Broadcasting, Linear Algebra
# **Total Marks: 25** | Time: 30 minutes

# %% [markdown]
# ## Section A — MCQ (1 mark each)
#
# **Q1.** `np.arange(0, 10, 2)` produces:
#
# a) `[0,2,4,6,8,10]`  b) `[0,2,4,6,8]`  c) `[2,4,6,8,10]`  d) `[0,2,4,6]`

# %%
answer_1 = ''

# %% [markdown]
# **Q2.** `arr.reshape(2, 3)` on a 6-element array produces a shape of:
#
# a) `(3, 2)`  b) `(6,)`  c) `(2, 3)`  d) Error

# %%
answer_2 = ''

# %% [markdown]
# **Q3.** In NumPy, `arr[arr > 5]` is called:
#
# a) Fancy indexing  b) Boolean masking  c) Slicing  d) Logical indexing

# %%
answer_3 = ''

# %% [markdown]
# **Q4.** `np.dot(a, b)` where `a` is `(2,3)` and `b` is `(3,4)` gives shape:
#
# a) `(2,4)`  b) `(3,3)`  c) `(2,3,4)`  d) Error

# %%
answer_4 = ''

# %% [markdown]
# **Q5.** `np.random.seed(42)` ensures:
#
# a) Truly random numbers  b) Reproducible random numbers  c) Numbers seeded from system clock  d) Faster generation

# %%
answer_5 = ''

# %% [markdown]
# ## Section B — True/False (1 mark each)
#
# **Q6.** NumPy arrays must contain elements of the same data type.
# **Q7.** `arr[1:4]` in NumPy returns a copy, not a view.
# **Q8.** Broadcasting allows operations between arrays of different shapes under certain rules.
# **Q9.** `np.linspace(0, 1, 5)` generates 5 evenly spaced values including both endpoints.
# **Q10.** `np.zeros((3,3))` creates a 3×3 matrix of ones.

# %%
answer_6=''
answer_7=''
answer_8=''
answer_9=''
answer_10=''

# %% [markdown]
# ## Section C — Short Answer (3 marks each)
#
# **Q11.** Why is NumPy significantly faster than Python lists for numerical computations?

# %%
answer_11 = """
...
"""

# %% [markdown]
# **Q12.** Explain what vectorization means and give an example.

# %%
answer_12 = """
...
"""

# %% [markdown]
# **Q13.** What are the three rules of NumPy broadcasting?

# %%
answer_13 = """
...
"""

# %% [markdown]
# ## Fill in the Blank (1 mark each)
#
# **Q14.** `np.array([1,2,3]).___` returns the shape of the array.
# **Q15.** To find the index of the maximum value in a 1D array, use `np.___`.

# %%
answer_14=''
answer_15=''

# %% [markdown]
# ## ✅ Answer Key

# %%
answers={1:'b',2:'c',3:'b',4:'a',5:'b',6:'True',7:'False',8:'True',9:'True',10:'False',
    11:'NumPy uses contiguous C-level memory and vectorized operations; no Python interpreter overhead per element.',
    12:'Vectorization applies an operation to an entire array at once rather than looping. E.g., arr * 2 doubles all elements.',
    13:'1) If shapes differ in ndim, prepend 1s. 2) Dimensions of size 1 stretch to match. 3) All dims must match or be 1.',
    14:'shape',15:'argmax'}
print('Key loaded.')
