# %% [markdown]
# # 💻 Coding Challenge — Week 8: Machine Learning
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** Preprocessing, Regression, Classification, Evaluation
# **Total Marks: 30** | Time: 60 minutes

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, classification_report
from sklearn.datasets import make_regression, make_classification
import warnings
warnings.filterwarnings('ignore')
np.random.seed(42)
print('Libraries loaded ✅')

# %% [markdown]
# ## Challenge 1 — Data Preprocessing Pipeline (6 marks)
#
# You are given a messy dataset. Preprocess it:
# 1. Encode `gender` with `LabelEncoder`
# 2. Fill missing `income` values with the median
# 3. Scale `age` and `income` using `StandardScaler`
# 4. Split into 80/20 train/test
# 5. Store as `X_train`, `X_test`, `y_train`, `y_test`

# %%
np.random.seed(0)
raw = pd.DataFrame({
    'age':    np.random.randint(20, 60, 100).astype(float),
    'gender': np.random.choice(['M','F'], 100),
    'income': np.where(np.random.rand(100) < 0.1, np.nan, np.random.randint(30000, 100000, 100).astype(float)),
    'bought': np.random.randint(0, 2, 100)
})

# ─── YOUR CODE HERE ───────────────────────────────────────────
X_train = X_test = y_train = y_test = None
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert X_train is not None and X_test is not None
assert len(X_train) == 80 and len(X_test) == 20
assert pd.DataFrame(X_train).isna().sum().sum() == 0
print('✅ Preprocessing passed — 6/6 marks')

# %% [markdown]
# ## Challenge 2 — Linear Regression (6 marks)
#
# 1. Generate regression data: `X, y = make_regression(n_samples=300, n_features=5, noise=20, random_state=42)`
# 2. Split 80/20, scale features
# 3. Train `LinearRegression`
# 4. Report `MSE` and `R²` on the test set
# 5. Store model as `reg_model`

# %%
# ─── YOUR CODE HERE ───────────────────────────────────────────
reg_model = None
mse = None
r2 = None
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert reg_model is not None
assert r2 is not None and r2 > 0.8, f'R² too low: {r2}'
print(f'MSE: {mse:.2f}  R²: {r2:.4f}')
print('✅ Linear Regression passed — 6/6 marks')

# %% [markdown]
# ## Challenge 3 — Logistic Regression Classifier (6 marks)
#
# 1. Generate: `X, y = make_classification(n_samples=500, n_features=10, random_state=42)`
# 2. Split 80/20, scale features
# 3. Train `LogisticRegression(max_iter=1000)`
# 4. Print `accuracy` and `classification_report`
# 5. Store model as `clf_model`

# %%
# ─── YOUR CODE HERE ───────────────────────────────────────────
clf_model = None
accuracy = None
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert clf_model is not None
assert accuracy is not None and accuracy > 0.80, f'Accuracy {accuracy:.2f} too low'
print(f'Accuracy: {accuracy:.4f}')
print('✅ Logistic Regression passed — 6/6 marks')

# %% [markdown]
# ## Challenge 4 — Cross Validation (6 marks)
#
# Using the classification dataset from Challenge 3:
# 1. Perform 5-fold cross validation on `LogisticRegression(max_iter=1000)` (before scaling for simplicity)
# 2. Print mean and std of CV scores
# 3. Store mean score as `cv_mean`

# %%
# ─── YOUR CODE HERE ───────────────────────────────────────────
cv_scores = None
cv_mean = None
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert len(cv_scores) == 5
assert cv_mean > 0.75, f'CV mean too low: {cv_mean}'
print(f'CV mean: {cv_mean:.4f} ± {cv_scores.std():.4f}')
print('✅ Cross-validation passed — 6/6 marks')

# %% [markdown]
# ## Challenge 5 — Model Comparison (6 marks)
#
# Using `make_classification(n_samples=400, n_features=8, random_state=1)`:
# Train and compare on test accuracy:
# - `LogisticRegression`
# - `sklearn.neighbors.KNeighborsClassifier(n_neighbors=5)`
#
# Print which model won and by how much.

# %%
from sklearn.neighbors import KNeighborsClassifier

# ─── YOUR CODE HERE ───────────────────────────────────────────
best_model_name = ''
best_accuracy = 0.0
# ──────────────────────────────────────────────────────────────

# %%
# --- CHECK ---
assert best_model_name in ['LogisticRegression', 'KNN', 'KNeighborsClassifier']
assert best_accuracy > 0.75
print(f'Best model: {best_model_name} with accuracy {best_accuracy:.4f}')
print('✅ Model comparison passed — 6/6 marks')
