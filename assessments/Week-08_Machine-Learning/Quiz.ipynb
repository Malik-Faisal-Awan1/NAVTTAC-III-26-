# %% [markdown]
# # 📝 Quiz — Week 8: Machine Learning Foundations
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** ML Workflow, Preprocessing, Regression, Classification
# **Total Marks: 30** | Time: 35 minutes

# %% [markdown]
# ## Section A — MCQ (1 mark each)
#
# **Q1.** The goal of **supervised learning** is:
#
# a) Find hidden patterns in unlabeled data
# b) Learn a mapping from input features to a known output label
# c) Optimize reward signals over time
# d) Compress data into lower dimensions

# %%
answer_1 = ''

# %% [markdown]
# **Q2.** Which metric is most appropriate when class imbalance is severe?
#
# a) Accuracy  b) Mean Squared Error  c) F1-Score  d) R²

# %%
answer_2 = ''

# %% [markdown]
# **Q3.** `StandardScaler` transforms data to:
#
# a) 0–1 range  b) Mean 0, unit variance  c) Median 0  d) Log scale

# %%
answer_3 = ''

# %% [markdown]
# **Q4.** What does `train_test_split(X, y, test_size=0.2)` do?
#
# a) 20% train, 80% test  b) 80% train, 20% test  c) 20 rows for test  d) 20% validation

# %%
answer_4 = ''

# %% [markdown]
# **Q5.** Logistic Regression is used for:
#
# a) Predicting continuous values  b) Classification  c) Clustering  d) Dimensionality reduction

# %%
answer_5 = ''

# %% [markdown]
# **Q6.** High bias in a model typically means:
#
# a) Overfitting  b) Underfitting  c) Good generalization  d) Data leakage

# %%
answer_6 = ''

# %% [markdown]
# ## Section B — True/False (1 mark each)
#
# **Q7.** R² of 1.0 means perfect predictions.
# **Q8.** Overfitting occurs when a model performs well on training data but poorly on test data.
# **Q9.** One-hot encoding converts categorical variables to numbers.
# **Q10.** A confusion matrix is used for regression problems.
# **Q11.** `cross_val_score` helps estimate model performance more reliably than a single train/test split.

# %%
answer_7=''
answer_8=''
answer_9=''
answer_10=''
answer_11=''

# %% [markdown]
# ## Section C — Short Answer (3 marks each)
#
# **Q12.** Explain the bias-variance tradeoff in simple terms.

# %%
answer_12 = """
...
"""

# %% [markdown]
# **Q13.** What is the difference between precision and recall? When is recall more important?

# %%
answer_13 = """
...
"""

# %% [markdown]
# **Q14.** Why should you scale features before training many ML algorithms?

# %%
answer_14 = """
...
"""

# %% [markdown]
# ## Fill in the Blank (1 mark each)
#
# **Q15.** The scikit-learn method to train a model is called `___.fit(X_train, y_train)`.
# **Q16.** To measure average absolute error, use the metric called ___.

# %%
answer_15=''
answer_16=''

# %% [markdown]
# ## ✅ Answer Key

# %%
answers={1:'b',2:'c',3:'b',4:'b',5:'b',6:'b',7:'True',8:'True',9:'True',10:'False',11:'True',
    12:'Bias = error from wrong assumptions (underfitting). Variance = sensitivity to training data (overfitting). Tradeoff: reducing one often increases the other.',
    13:'Precision = TP/(TP+FP): how many positives are real. Recall = TP/(TP+FN): how many real positives were found. Recall matters more when missing a positive is costly (e.g., cancer detection).',
    14:'Many algorithms (SVM, KNN, regression with regularization) are sensitive to feature magnitude. Without scaling, large-magnitude features dominate.',
    15:'model (estimator)',16:'Mean Absolute Error (MAE)'}
print('Key loaded.')
