# %% [markdown]
# # 📝 Quiz — Week 9: Advanced Machine Learning
# **Course:** Advanced Python Programming — NAVTTC
# **Topics:** Decision Trees, Ensembles, Model Selection, Clustering
# **Total Marks: 30** | Time: 35 minutes

# %% [markdown]
# ## Section A — MCQ (1 mark each)
#
# **Q1.** A Decision Tree splits data based on:
#
# a) Random features  b) The feature that maximizes information gain  c) The last column  d) Distance from centroid

# %%
answer_1 = ''

# %% [markdown]
# **Q2.** Random Forest reduces overfitting by:
#
# a) Using one deep tree  b) Averaging predictions of many trees trained on random subsets  c) Removing features  d) Increasing learning rate

# %%
answer_2 = ''

# %% [markdown]
# **Q3.** `GridSearchCV` is used to:
#
# a) Visualize a grid  b) Tune hyperparameters by exhaustive search  c) Scale features  d) Split data

# %%
answer_3 = ''

# %% [markdown]
# **Q4.** In K-Means clustering, `k` refers to:
#
# a) Number of features  b) Number of iterations  c) Number of clusters  d) Learning rate

# %%
answer_4 = ''

# %% [markdown]
# **Q5.** Which ensemble method trains models **sequentially**, each correcting the previous?
#
# a) Bagging  b) Random Forest  c) Boosting  d) Stacking

# %%
answer_5 = ''

# %% [markdown]
# **Q6.** The **elbow method** helps determine:
#
# a) Best learning rate  b) Optimal number of clusters K  c) Tree depth  d) Regularization strength

# %%
answer_6 = ''

# %% [markdown]
# ## Section B — True/False (1 mark each)
#
# **Q7.** Pruning a decision tree helps reduce overfitting.
# **Q8.** Gradient Boosting is an ensemble of trees where each tree corrects the residuals of the previous.
# **Q9.** K-Means requires you to specify the number of clusters in advance.
# **Q10.** `max_depth` in a Decision Tree limits overfitting.
# **Q11.** PCA is a supervised dimensionality reduction method.

# %%
answer_7=''
answer_8=''
answer_9=''
answer_10=''
answer_11=''

# %% [markdown]
# ## Short Answer (3 marks each)
#
# **Q12.** Explain bagging vs boosting in simple terms.

# %%
answer_12 = """
...
"""

# %% [markdown]
# **Q13.** What is inertia in K-Means and why do we want it low?

# %%
answer_13 = """
...
"""

# %% [markdown]
# **Q14.** Why is it important to NOT use the test set when performing cross-validation?

# %%
answer_14 = """
...
"""

# %% [markdown]
# ## Fill in the Blank
#
# **Q15.** `RandomForestClassifier(n_estimators=___)` controls how many trees are built.
# **Q16.** A silhouette score close to ___ indicates well-separated clusters.

# %%
answer_15=''
answer_16=''

# %% [markdown]
# ## ✅ Answer Key

# %%
answers={1:'b',2:'b',3:'b',4:'c',5:'c',6:'b',7:'True',8:'True',9:'True',10:'True',11:'False',
    12:'Bagging trains models in parallel on random subsets and averages (reduces variance). Boosting trains sequentially; each model fixes previous errors (reduces bias).',
    13:'Inertia = sum of squared distances from each point to its cluster centroid. Low inertia = tight clusters.',
    14:'Using test set for hyperparameter tuning causes data leakage — the model indirectly learns from test data, giving overly optimistic performance.',
    15:'100 (or any number)',16:'1'}
print('Key loaded.')
